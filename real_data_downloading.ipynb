# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("garymk/movielens-25m-dataset",output_dir="./data/movie",force_download=True)

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 258M/258M [00:16<00:00, 16.8MB/s]
# Extracting files...
# Path to dataset files: ./data/movie

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("annnnguyen/metr-la-dataset",output_dir="./data/metr",force_download=True)

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 12.5M/12.5M [00:01<00:00, 8.62MB/s]
# Extracting files...
# Path to dataset files: ./data/metr

# %% [markdown]
# ### Note do pracy:
#
# Gdy syntetyczne badają jakość metody i czy przy wykorzystaniu założeń nasza metoda rzeczywiście zyskuje. Testy na realnych danych weryfikują bardziej czy nasze założenia na temat danych mają jakieś odzwierciedlenie w rzeczywistości
