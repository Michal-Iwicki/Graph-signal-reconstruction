# %%
from codes.testing import run_psd_experiment
run_psd_experiment(M =100)

# %%
from codes.testing import reconstruction_experiment
_=reconstruction_experiment(M_train=100,gm_beta=0.001)
# Out:
# === Reconstruction results (p=0.5) ===
# MAE PSD: 0.0121
# MAE GM : 0.0404

# %%
_ = reconstruction_experiment(100,20, M_train=100, gm_beta=0.001)
# Out:
# === Reconstruction results (p=0.5) ===
# MAE PSD: 0.0080
# MAE GM : 0.0305

# %% [markdown]
# Dwa pomysły na grupowanie, pierwszy zbudować macierz podobienstwa pomiedzy obserwacjami a nastepnie użyc algorytmu klastrowania jak spectral clustering czy kmeans(z rekonstrukcja poprzez smoothness albo inna opcja jak ignorować braki)

# %% [markdown]
# Druga opcja statystycznie Dopasować rozkłady bazująć na założeniu gaussian mixture

# %% [markdown]
# Quick visualization how validation of assumption affects quality of estimation

# %%
from codes.testing import run_mixed_psd_estimation_exp

# %%
_= run_mixed_psd_estimation_exp()

# %%
from codes.testing import run_mixed_comparison_experiment
run_mixed_comparison_experiment()
# Out:
# === Aggregate Results (Mean MAE) ===
#                          Informed MAE  Global MAE
# Type
# Mid-Band A (Low-Shift)       0.037278    0.160922
# Mid-Band B (High-Shift)      1.026560    1.033321
#                        Type  Informed MAE  Global MAE
# 0   Mid-Band B (High-Shift)      1.037821    1.036227
# 1   Mid-Band B (High-Shift)      1.054029    1.071962
# 2    Mid-Band A (Low-Shift)      0.054741    0.210496
# 3    Mid-Band A (Low-Shift)      0.042361    0.136941
# 4    Mid-Band A (Low-Shift)      0.034704    0.144206
# ..                      ...           ...         ...
# 95  Mid-Band B (High-Shift)      1.011864    1.040089
# 96  Mid-Band B (High-Shift)      1.175528    1.152694
# 97  Mid-Band B (High-Shift)      1.065473    1.052344
# 98   Mid-Band A (Low-Shift)      0.027941    0.191047
# 99  Mid-Band B (High-Shift)      0.929876    0.964682
#
# [100 rows x 3 columns]
