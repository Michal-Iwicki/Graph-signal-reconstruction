# %%
from codes.testing import run_psd_experiment
run_psd_experiment()

# %% [markdown]
# Clustering z regulized cut, tylko inaczej trzeba zbudować podobieństwo, może statystycznie porownac rozklad ale to noisy.

# %% [markdown]
# Druga opcja uzyc smoothnes i potem pogrupować poprzez kmeans czy inny algorytm np ten spectral clustering z ujemnymi wartosciami, ale to też wymaga zbudowania macierzy podobieństwa
